# %%
import pandas as pd
from lxml import etree
from lxml import objectify

precip_Northeast_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/101-pcp-all-1-2000-2020.xml'
precip_Northeast_raw = objectify.parse(open(precip_Northeast_path))
precip_Northeast_root = precip_Northeast_raw.getroot()
precip_Northeast_data = []
for elt in precip_Northeast_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_Northeast_data.append(xml_data)    
precip_Northeast = pd.DataFrame(precip_Northeast_data)
precip_Northeast['Region'] = 'Northeast'

precip_UpperMidwest_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/102-pcp-all-1-2000-2020.xml'
precip_UpperMidwest_raw = objectify.parse(open(precip_UpperMidwest_path))
precip_UpperMidwest_root = precip_UpperMidwest_raw.getroot()
precip_UpperMidwest_data = []
for elt in precip_UpperMidwest_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_UpperMidwest_data.append(xml_data)    
precip_UpperMidwest = pd.DataFrame(precip_UpperMidwest_data)
precip_UpperMidwest['Region'] = 'Upper Midwest'

precip_OhioValley_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/103-pcp-all-1-2000-2020.xml'
precip_OhioValley_raw = objectify.parse(open(precip_OhioValley_path))
precip_OhioValley_root = precip_OhioValley_raw.getroot()
precip_OhioValley_data = []
for elt in precip_OhioValley_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_OhioValley_data.append(xml_data)    
precip_OhioValley = pd.DataFrame(precip_OhioValley_data)
precip_OhioValley['Region'] = 'Ohio Valley'

precip_Southeast_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/104-pcp-all-1-2000-2020.xml'
precip_Southeast_raw = objectify.parse(open(precip_Southeast_path))
precip_Southeast_root = precip_Southeast_raw.getroot()
precip_Southeast_data = []
for elt in precip_Southeast_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_Southeast_data.append(xml_data)    
precip_Southeast = pd.DataFrame(precip_Southeast_data)
precip_Southeast['Region'] = 'Southeast'

precip_NorthernRockies_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/105-pcp-all-1-2000-2020.xml'
precip_NorthernRockies_raw = objectify.parse(open(precip_NorthernRockies_path))
precip_NorthernRockies_root = precip_NorthernRockies_raw.getroot()
precip_NorthernRockies_data = []
for elt in precip_NorthernRockies_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_NorthernRockies_data.append(xml_data)    
precip_NorthernRockies = pd.DataFrame(precip_NorthernRockies_data)
precip_NorthernRockies['Region'] = 'Northern Rockies'

precip_South_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/106-pcp-all-1-2000-2020.xml'
precip_South_raw = objectify.parse(open(precip_South_path))
precip_South_root = precip_South_raw.getroot()
precip_South_data = []
for elt in precip_South_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_South_data.append(xml_data)    
precip_South = pd.DataFrame(precip_South_data)
precip_South['Region'] = 'South'

precip_Southwest_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/107-pcp-all-1-2000-2020.xml'
precip_Southwest_raw = objectify.parse(open(precip_Southwest_path))
precip_Southwest_root = precip_Southwest_raw.getroot()
precip_Southwest_data = []
for elt in precip_Southwest_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_Southwest_data.append(xml_data)    
precip_Southwest = pd.DataFrame(precip_Southwest_data)
precip_Southwest['Region'] = 'Southwest'

precip_Northwest_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/108-pcp-all-1-2000-2020.xml'
precip_Northwest_raw = objectify.parse(open(precip_Northwest_path))
precip_Northwest_root = precip_Northwest_raw.getroot()
precip_Northwest_data = []
for elt in precip_Northwest_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_Northwest_data.append(xml_data)    
precip_Northwest = pd.DataFrame(precip_Northwest_data)
precip_Northwest['Region'] = 'Northwest'

precip_West_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/109-pcp-all-1-2000-2020.xml'
precip_West_raw = objectify.parse(open(precip_West_path))
precip_West_root = precip_West_raw.getroot()
precip_West_data = []
for elt in precip_West_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    precip_West_data.append(xml_data)    
precip_West = pd.DataFrame(precip_West_data)
precip_West['Region'] = 'West'

avgtemp_Northeast_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/101-tavg-all-1-2000-2020.xml'
avgtemp_Northeast_raw = objectify.parse(open(avgtemp_Northeast_path))
avgtemp_Northeast_root = avgtemp_Northeast_raw.getroot()
avgtemp_Northeast_data = []
for elt in avgtemp_Northeast_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_Northeast_data.append(xml_data)    
avgtemp_Northeast = pd.DataFrame(avgtemp_Northeast_data)
avgtemp_Northeast['Region'] = 'Northeast'

avgtemp_UpperMidwest_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/102-tavg-all-1-2000-2020.xml'
avgtemp_UpperMidwest_raw = objectify.parse(open(avgtemp_UpperMidwest_path))
avgtemp_UpperMidwest_root = avgtemp_UpperMidwest_raw.getroot()
avgtemp_UpperMidwest_data = []
for elt in avgtemp_UpperMidwest_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_UpperMidwest_data.append(xml_data)    
avgtemp_UpperMidwest = pd.DataFrame(avgtemp_UpperMidwest_data)
avgtemp_UpperMidwest['Region'] = 'Upper Midwest'

avgtemp_OhioValley_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/103-tavg-all-1-2000-2020.xml'
avgtemp_OhioValley_raw = objectify.parse(open(avgtemp_OhioValley_path))
avgtemp_OhioValley_root = avgtemp_OhioValley_raw.getroot()
avgtemp_OhioValley_data = []
for elt in avgtemp_OhioValley_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_OhioValley_data.append(xml_data)    
avgtemp_OhioValley = pd.DataFrame(avgtemp_OhioValley_data)
avgtemp_OhioValley['Region'] = 'Ohio Valley'

avgtemp_Southeast_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/104-tavg-all-1-2000-2020.xml'
avgtemp_Southeast_raw = objectify.parse(open(avgtemp_Southeast_path))
avgtemp_Southeast_root = avgtemp_Southeast_raw.getroot()
avgtemp_Southeast_data = []
for elt in avgtemp_Southeast_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_Southeast_data.append(xml_data)    
avgtemp_Southeast = pd.DataFrame(avgtemp_Southeast_data)
avgtemp_Southeast['Region'] = 'Southeast'

avgtemp_NorthernRockies_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/105-tavg-all-1-2000-2020.xml'
avgtemp_NorthernRockies_raw = objectify.parse(open(avgtemp_NorthernRockies_path))
avgtemp_NorthernRockies_root = avgtemp_NorthernRockies_raw.getroot()
avgtemp_NorthernRockies_data = []
for elt in avgtemp_NorthernRockies_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_NorthernRockies_data.append(xml_data)    
avgtemp_NorthernRockies = pd.DataFrame(avgtemp_NorthernRockies_data)
avgtemp_NorthernRockies['Region'] = 'Northern Rockies'

avgtemp_South_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/106-tavg-all-1-2000-2020.xml'
avgtemp_South_raw = objectify.parse(open(avgtemp_South_path))
avgtemp_South_root = avgtemp_South_raw.getroot()
avgtemp_South_data = []
for elt in avgtemp_South_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_South_data.append(xml_data)    
avgtemp_South = pd.DataFrame(avgtemp_South_data)
avgtemp_South['Region'] = 'South'

avgtemp_Southwest_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/107-tavg-all-1-2000-2020.xml'
avgtemp_Southwest_raw = objectify.parse(open(avgtemp_Southwest_path))
avgtemp_Southwest_root = avgtemp_Southwest_raw.getroot()
avgtemp_Southwest_data = []
for elt in avgtemp_Southwest_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_Southwest_data.append(xml_data)    
avgtemp_Southwest = pd.DataFrame(avgtemp_Southwest_data)
avgtemp_Southwest['Region'] = 'Southwest'

avgtemp_Northwest_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/108-tavg-all-1-2000-2020.xml'
avgtemp_Northwest_raw = objectify.parse(open(avgtemp_Northwest_path))
avgtemp_Northwest_root = avgtemp_Northwest_raw.getroot()
avgtemp_Northwest_data = []
for elt in avgtemp_Northwest_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_Northwest_data.append(xml_data)    
avgtemp_Northwest = pd.DataFrame(avgtemp_Northwest_data)
avgtemp_Northwest['Region'] = 'Northwest'

avgtemp_West_path = 'C:/Users/mithr/Desktop/Data Science Masters/DSC 540/Term Project/NOAA XML/109-tavg-all-1-2000-2020.xml'
avgtemp_West_raw = objectify.parse(open(avgtemp_West_path))
avgtemp_West_root = avgtemp_West_raw.getroot()
avgtemp_West_data = []
for elt in avgtemp_West_root.data:
    xml_data = {}
    for child in elt.getchildren():
        xml_data[child.tag] = child.pyval
    avgtemp_West_data.append(xml_data)    
avgtemp_West = pd.DataFrame(avgtemp_West_data)
avgtemp_West['Region'] = 'West'

# %%
precip_Northeast = precip_Northeast.rename(columns = {'value': 'Total precipitation (inches)'})
precip_UpperMidwest = precip_UpperMidwest.rename(columns = {'value': 'Total precipitation (inches)'})
precip_OhioValley = precip_OhioValley.rename(columns = {'value': 'Total precipitation (inches)'})
precip_Southeast = precip_Southeast.rename(columns = {'value': 'Total precipitation (inches)'})
precip_NorthernRockies = precip_NorthernRockies.rename(columns = {'value': 'Total precipitation (inches)'})
precip_South = precip_South.rename(columns = {'value': 'Total precipitation (inches)'})
precip_Southwest = precip_Southwest.rename(columns = {'value': 'Total precipitation (inches)'})
precip_Northwest = precip_Northwest.rename(columns = {'value': 'Total precipitation (inches)'})
precip_West = precip_West.rename(columns = {'value': 'Total precipitation (inches)'})
avgtemp_Northeast = avgtemp_Northeast.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_UpperMidwest = avgtemp_UpperMidwest.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_OhioValley = avgtemp_OhioValley.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_Southeast = avgtemp_Southeast.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_NorthernRockies = avgtemp_NorthernRockies.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_South = avgtemp_South.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_Southwest = avgtemp_Southwest.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_Northwest = avgtemp_Northwest.rename(columns = {'value': 'Average temperature (°F)'})
avgtemp_West = avgtemp_West.rename(columns = {'value': 'Average temperature (°F)'})

# %%
precip_I = pd.merge(precip_Northeast, precip_UpperMidwest, how='outer')
precip_II = pd.merge(precip_I, precip_OhioValley, how='outer')
precip_III = pd.merge(precip_II, precip_Southeast, how='outer')
precip_IV = pd.merge(precip_III, precip_NorthernRockies, how='outer')
precip_V = pd.merge(precip_IV, precip_South, how='outer')
precip_VI = pd.merge(precip_V, precip_Southwest, how='outer')
precip_VII = pd.merge(precip_VI, precip_Northwest, how='outer')
precip_final = pd.merge(precip_VII, precip_West, how='outer')

avgtemp_I = pd.merge(avgtemp_Northeast, avgtemp_UpperMidwest, how='outer')
avgtemp_II = pd.merge(avgtemp_I, avgtemp_OhioValley, how='outer')
avgtemp_III = pd.merge(avgtemp_II, avgtemp_Southeast, how='outer')
avgtemp_IV = pd.merge(avgtemp_III, avgtemp_NorthernRockies, how='outer')
avgtemp_V = pd.merge(avgtemp_IV, avgtemp_South, how='outer')
avgtemp_VI = pd.merge(avgtemp_V, avgtemp_Southwest, how='outer')
avgtemp_VII = pd.merge(avgtemp_VI, avgtemp_Northwest, how='outer')
avgtemp_final = pd.merge(avgtemp_VII, avgtemp_West, how='outer')

climate_data = pd.merge(precip_final, avgtemp_final, how='outer')
climate_data['date'] = pd.to_datetime(climate_data['date'], format = '%Y%m')
climate_data['date'] = climate_data['date'].dt.strftime('%b-%Y')
climate_data = climate_data.rename(columns = {'date': 'Month and Year'})

print(climate_data)
# Out:
#      Month and Year  Total precipitation (inches)     Region  \
# 0          Jan-2000                          3.17  Northeast
# 1          Feb-2000                          2.92  Northeast
# 2          Mar-2000                          3.62  Northeast
# 3          Apr-2000                          5.09  Northeast
# 4          May-2000                          4.81  Northeast
# ...             ...                           ...        ...
# 2164       Sep-2019                          0.69       West
# 2165       Oct-2019                          0.14       West
# 2166       Nov-2019                          1.35       West
# 2167       Dec-2019                          3.46       West
# 2168       Jan-2020                          1.50       West
#
#       Average temperature (°F)
# 0                         21.4
# 1                         27.2
# 2                         39.1
# 3                         44.2
# 4                         56.6
# ...                        ...
# ...

# %%
climate_data.to_csv('Climate Data (clean).csv')
