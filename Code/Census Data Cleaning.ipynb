# %%
import pandas

census_raw = pandas.read_csv("ACSCP5Y2018.CP03_data_with_overlays_2020-04-03T201900.csv")
print(census_raw.head(5))
# Out:
#                id     Geographic Area Name  \
# 0  0500000US01001  Autauga County, Alabama
# 1  0500000US01003  Baldwin County, Alabama
# 2  0500000US01005  Barbour County, Alabama
# 3  0500000US01007     Bibb County, Alabama
# 4  0500000US01009   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2009-2013 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               56.7
# 1                                               54.8
# 2                                               42.4
# ...

# %%
census_clean1 = census_raw.drop(['id'], axis = 1)
print(census_clean1.head(5))
# Out:
#       Geographic Area Name  \
# 0  Autauga County, Alabama
# 1  Baldwin County, Alabama
# 2  Barbour County, Alabama
# 3     Bibb County, Alabama
# 4   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2009-2013 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               56.7
# 1                                               54.8
# 2                                               42.4
# 3                                               43.6
# 4                                               50.6
#
# ...

# %%
census_clean2 = census_clean1.loc[:,~census_clean1.columns.str.contains('Statistical Significance')]
print(census_clean2.head(5))
# Out:
#       Geographic Area Name  \
# 0  Autauga County, Alabama
# 1  Baldwin County, Alabama
# 2  Barbour County, Alabama
# 3     Bibb County, Alabama
# 4   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2009-2013 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               56.7
# 1                                               54.8
# 2                                               42.4
# 3                                               43.6
# 4                                               50.6
#
# ...

# %%
census_clean3 = census_clean2.loc[:,~census_clean2.columns.str.contains('2009-2013 Estimate')]
print(census_clean3.head(5))
# Out:
#       Geographic Area Name  \
# 0  Autauga County, Alabama
# 1  Baldwin County, Alabama
# 2  Barbour County, Alabama
# 3     Bibb County, Alabama
# 4   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed  \
# 0                                                2.5
# 1                                                2.6
# 2                                                4.4
# 3                                                3.6
# 4                                                  2
#
# ...

# %%
census_clean4 = census_clean3.loc[:,~census_clean3.columns.str.contains('POVERTY')]
print(census_clean4.head(5))
# Out:
#       Geographic Area Name  \
# 0  Autauga County, Alabama
# 1  Baldwin County, Alabama
# 2  Barbour County, Alabama
# 3     Bibb County, Alabama
# 4   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed  \
# 0                                                2.5
# 1                                                2.6
# 2                                                4.4
# 3                                                3.6
# 4                                                  2
#
# ...

# %%
census_clean5 = census_clean4.loc[:,~census_clean4.columns.str.contains('HEALTH INSURANCE')]
print(census_clean5.head(5))
# Out:
#       Geographic Area Name  \
# 0  Autauga County, Alabama
# 1  Baldwin County, Alabama
# 2  Barbour County, Alabama
# 3     Bibb County, Alabama
# 4   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed  \
# 0                                                2.5
# 1                                                2.6
# 2                                                4.4
# 3                                                3.6
# 4                                                  2
#
# ...

# %%
census_clean6 = census_clean5.drop(['2014-2018 Estimate!!INDUSTRY!!Civilian employed population 16 years and over', '2014-2018 Estimate!!CLASS OF WORKER!!Civilian employed population 16 years and over'], axis = 1)  ## duplicated data; all the same as '2014-2018 Estimate!!COMMUTING TO WORK!!Workers 16 years and over'
print(census_clean6.head(5))
# Out:
#       Geographic Area Name  \
# 0  Autauga County, Alabama
# 1  Baldwin County, Alabama
# 2  Barbour County, Alabama
# 3     Bibb County, Alabama
# 4   Blount County, Alabama
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# 0                                               55.6
# 1                                               55.7
# 2                                               41.6
# 3                                               43.8
# 4                                               46.5
#
#   2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed  \
# 0                                                2.5
# 1                                                2.6
# 2                                                4.4
# 3                                                3.6
# 4                                                  2
#
# ...

# %%
print(census_clean6.columns.values)
# Out:
# ['Geographic Area Name'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Civilian labor force'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Females 16 years and over'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force!!Civilian labor force'
#  '2014-2018 Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force!!Civilian labor force!!Employed'
# ...

# %%
census_clean6.columns = ['Location', 'Population 16+ years employed in civilian labor force', 'Population 16+ years unemployed in civilian labor force', 'Population 16+ years in Armed Forces', 'Population 16+ years not in labor force', 'Total civilian labor force', 'Unemployment Rate of civilian labor force', 'Total females 16+ years', 'Females 16+ years in labor force', 'Females 16+ years in civilian labor force', 'Females 16+ years employed in civilian labor force', 'Total children of the householder under 6 years', 'All parents in family in labor force with children of the householder under 6 years', 'Total children of the householder 6 to 17 years', 'All parents in family in labor force with children of the householder 6 to 17 years', 'Total workers 16+ years', 'Workers 16+ years commute alone in car, truck, or van', 'Workers 16+ years commute by carpool (car, truck, or van)', 'Workers 16+ years commute by public transportation (excluding taxicab)', 'Workers 16+ years commute by walking', 'Workers 16+ years commuted by other means', 'Workers 16+ years worked at home', 'Mean travel time to work (minutes)', 'Civilian employed population 16+ years', 'Civilian employed population 16+ years in management, business, science, and arts occupations', 'Civilian employed population 16+ years in service occupations', 'Civilian employed population 16+ years in sales and office occupations', 'Civilian employed population 16+ years in natural resources, construction, and maintenance occupations', 'Civilian employed population 16+ years in production, transportation, and material moving occupations', 'Civilian employed population 16+ years in agriculture, forestry, fishing and hunting, and mining', 'Civilian employed population 16+ years in construction', 'Civilian employed population 16+ years in manufacturing', 'Civilian employed population 16+ years in wholesale trade', 'Civilian employed population 16+ years in retail trade', 'Civilian employed population 16+ years in transportation and warehousing, and utilities', 'Civilian employed population 16+ years in information', 'Civilian employed population 16+ years in finance and insurance, and real estate and rental and leasing', 'Civilian employed population 16+ years in professional, scientific, and management, and administrative and waste management services', 'Civilian employed population 16+ years in educational services, and health care and social assistance', 'Civilian employed population 16+ years in arts, entertainment, and recreation, and accommodation and food services', 'Civilian employed population 16+ years in other services, except public administration', 'Civilian employed population 16+ years in public administration', 'Civilian employed population 16+ years in private wage and salary workers', 'Civilian employed population 16+ years in government workers', 'Civilian employed population 16+ years in self-employed in own not incorporated business workers', 'Civilian employed population 16+ years in unpaid family workers', 'Total households', 'Households with income less than $10,000 (in 2018 inflation-adjusted dollars)', 'Households with income $10,000 to $14,999 (in 2018 inflation-adjusted dollars)', 'Households with income $15,000 to $24,999 (in 2018 inflation-adjusted dollars)', 'Households with income $25,000 to $34,999 (in 2018 inflation-adjusted dollars)', 'Households with income $35,000 to $49,999 (in 2018 inflation-adjusted dollars)', 'Households with income $50,000 to $74,999 (in 2018 inflation-adjusted dollars)', 'Households with income $75,000 to $99,999 (in 2018 inflation-adjusted dollars)', 'Households with income $100,000 to $149,999 (in 2018 inflation-adjusted dollars)', 'Households with income $150,000 to $199,999 (in 2018 inflation-adjusted dollars)', 'Households with income $200,000 or more (in 2018 inflation-adjusted dollars)', 'Median household income (dollars) (in 2018 inflation-adjusted dollars)', 'Mean household income (dollars) (in 2018 inflation-adjusted dollars)', 'Households with income through earnings (in 2018 inflation-adjusted dollars)', 'Mean income (dollars) of households with income through earnings (in 2018 inflation-adjusted dollars)', 'Households with income through Social Security', 'Mean income (dollars) of households with income through Social Security (in 2018 inflation-adjusted dollars)', 'Households with income through retirement income', 'Mean income (dollars) of households with income through retirement income (in 2018 inflation-adjusted dollars)', 'Households with income through Supplemental Security Income', 'Mean income (dollars) of  households with income through Supplemental Security Income (in 2018 inflation-adjusted dollars)', 'Households with income through cash public assistance income', 'Mean income (dollars) of households with income through cash public assistance income (in 2018 inflation-adjusted dollars)', 'Households with Food Stamp/SNAP benefits in the past 12 months', 'Total family households', 'Family households with income less than $10,000 (in 2018 inflation-adjusted dollars)', 'Family households with income $10,000 to $14,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $15,000 to $24,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $25,000 to $34,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $35,000 to $49,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $50,000 to $74,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $75,000 to $99,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $100,000 to $149,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $150,000 to $199,999 (in 2018 inflation-adjusted dollars)', 'Family households with income $200,000 or more (in 2018 inflation-adjusted dollars)', 'Median family income (dollars) (in 2018 inflation-adjusted dollars)', 'Mean family income (dollars) (in 2018 inflation-adjusted dollars)', 'Per capita income (dollars) (in 2018 inflation-adjusted dollars)', 'Total nonfamily households', 'Median nonfamily income (dollars) (in 2018 inflation-adjusted dollars)', 'Mean nonfamily income (dollars) (in 2018 inflation-adjusted dollars)', 'Median earnings for workers (dollars) (in 2018 inflation-adjusted dollars)', 'Median earnings for male full-time, year-round workers (dollars) (in 2018 inflation-adjusted dollars)', 'Median earnings for female full-time, year-round workers (dollars) (in 2018 inflation-adjusted dollars)', 'Total population 16+ years', 'Population 16+ years in labor force', 'Population 16+ years in civilian labor force']
census_clean7 = census_clean6
print(census_clean7)
# Out:
#                         Location  \
# 0        Autauga County, Alabama
# 1        Baldwin County, Alabama
# 2        Barbour County, Alabama
# 3           Bibb County, Alabama
# 4         Blount County, Alabama
# ...                          ...
# 5693  Sweetwater County, Wyoming
# 5694       Teton County, Wyoming
# 5695       Uinta County, Wyoming
# 5696    Washakie County, Wyoming
# 5697      Weston County, Wyoming
#
#      Population 16+ years employed in civilian labor force  \
# 0                                                  55.6
# 1                                                  55.7
# 2                                                  41.6
# 3                                                  43.8
# 4                                                  46.5
# ...                                                 ...
# 5693                                                 66
# 5694                                               75.4
# ...

# %%
census_cleaned = census_clean7.drop_duplicates(['Location'])
print(census_cleaned)
# Out:
#                               Location  \
# 0              Autauga County, Alabama
# 1              Baldwin County, Alabama
# 2              Barbour County, Alabama
# 3                 Bibb County, Alabama
# 4               Blount County, Alabama
# ...                                ...
# 2901  Vega Baja Municipio, Puerto Rico
# 2902    Vieques Municipio, Puerto Rico
# 2903   Villalba Municipio, Puerto Rico
# 2904    Yabucoa Municipio, Puerto Rico
# 2905      Yauco Municipio, Puerto Rico
#
#      Population 16+ years employed in civilian labor force  \
# 0                                                  55.6
# 1                                                  55.7
# 2                                                  41.6
# 3                                                  43.8
# 4                                                  46.5
# ...                                                 ...
# 2901                                               32.7
# ...

# %%
census_cleaned.to_csv('Census Data (clean).csv')
